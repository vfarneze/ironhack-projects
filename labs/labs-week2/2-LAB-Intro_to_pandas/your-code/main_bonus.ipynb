# %% [markdown]
# # Introduction to Pandas
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# Please Check the "main" jupyter arquive!!!

# %% [markdown]
# # BONUS

# %% [markdown]
# #### 1 Create a random dataframe containing 3 columns and 10 rows.
#
# *Hint: You'll have to use a `numpy.random` method to create random observations*

# %%
import numpy as np
import pandas as pd

random_array = np.random.random((10,3))
print(random_array)

df = pd.DataFrame(random_array)
print(df)
# Out:
# [[0.93470251 0.83322532 0.34183148]
#  [0.70249993 0.19841439 0.29087233]
#  [0.72531664 0.45851413 0.49405856]
#  [0.37073648 0.53829246 0.79484511]
#  [0.0043749  0.98897067 0.94665295]
#  [0.85983783 0.15715494 0.90224844]
#  [0.3369753  0.64716867 0.52850681]
#  [0.54649732 0.49951478 0.0230561 ]
#  [0.54510583 0.97619043 0.69954005]
#  [0.01155543 0.91500659 0.77325216]]
#           0         1         2
# 0  0.934703  0.833225  0.341831
# 1  0.702500  0.198414  0.290872
# 2  0.725317  0.458514  0.494059
# 3  0.370736  0.538292  0.794845
# 4  0.004375  0.988971  0.946653
# 5  0.859838  0.157155  0.902248
# 6  0.336975  0.647169  0.528507
# 7  0.546497  0.499515  0.023056
# 8  0.545106  0.976190  0.699540
# 9  0.011555  0.915007  0.773252

# %% [markdown]
# #### 2 Create a random dataframe containing 3 columns and 10 rows with specific column names.
#
# Use `['column1', 'column2', 'column3']` as the column names.

# %%
df2 = pd.DataFrame(np.random.random((10,3)), columns = ['column1', 'column2', 'column3'])
df2
# Out:
#     column1   column2   column3
# 0  0.005404  0.619521  0.656104
# 1  0.629648  0.037413  0.401850
# 2  0.582297  0.968273  0.415441
# 3  0.896033  0.958956  0.254968
# 4  0.740354  0.424801  0.273654
# 5  0.788799  0.329178  0.788045
# 6  0.208142  0.277027  0.616849
# 7  0.574478  0.513601  0.086460
# 8  0.254989  0.389783  0.226204
# 9  0.418372  0.490723  0.277804

# %% [markdown]
# #### 3 Create a random dataframe containing N columns and M rows with specific column names.
#
# For this task you'll have to name the columns as `['column1', 'column2', 'column3', ...,'columnN']`. You can use a list comprehension to do that.

# %%
N = 10
M = 30
list_of_columns = [f'column{number+1}' for number in range(N)]

df3 = pd.DataFrame(data=np.random.random((M,N)), columns = list_of_columns)
df3
# Out:
#      column1   column2   column3   column4   column5   column6   column7  \
# 0   0.547366  0.888593  0.871351  0.767691  0.916317  0.599172  0.815745
# 1   0.665239  0.008172  0.052597  0.249058  0.359730  0.907138  0.028621
# 2   0.545164  0.955399  0.891313  0.473454  0.640474  0.269838  0.077901
# 3   0.246498  0.438675  0.656329  0.297877  0.208926  0.167349  0.137630
# 4   0.973632  0.790932  0.187479  0.035027  0.838714  0.207376  0.233171
# 5   0.544596  0.666668  0.980371  0.606277  0.161444  0.464101  0.302449
# 6   0.269923  0.712602  0.350880  0.748319  0.848992  0.775118  0.603120
